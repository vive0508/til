# %% [markdown]
# # [Pandas] DataFrame

# %% [markdown]
# ## 1. 개요

# %% [markdown]
# ### 1.1 라이브러리 임포트

# %% [markdown]
# | **라이브러리명** | **용도** | **별칭** | **import 구문 예시** |
# | :--- | :--- | :--- | :--- |
# | \*numpy | 수치형 자료 계산 및 연산 | np | import numpy as np |
# | \*pandas | 정형 데이터 전처리 및 분석 | pd | import pandas as pd |
# | matplotlib | 데이터 차트 시각화 | plt | import matplotlib.pyplot as plt |
# | seaborn | 보다 개선된 데이터 시각화 | sns | import seaborn as sns |
# | beautifulsoup4(bs4) | 웹 데이터 추출(web scraping) |   | from bs4 import ~~ |
# | nltk | 자연어 데이터 전처리 |   | import nltk |
# | scikit-learn | 전통적인 머신러닝 알고리즘 |   | from sklearn import ~~ |

# %% [markdown]
# ### 1.2 pandas
# - 데이터타입
#     - Series : index, value
#     - DataFrame : index, value, column

# %%
# Pandas는 Numpy를 기반으로 만들어졌다.
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.3 예제 데이터 생성

# %%
# random

import random as r

r.random() : 0부터 1까지의 부동소수점 숫자를 리턴
r.randint(a, b) : a부터 b까지의 임의의 정수를 리턴
r.uniform(a, b) : a부터 b까지의 부동소수점 숫자를 리턴
r.randn() : 가우시안 표준 정규분포
r.randrange(a, b, n) : range(a,b,n)에서 랜덤하게 숫자를 리턴
r.shuffle(l) : 안에 있는 요소의 순서를 섞어 리턴
r.choice(l) : 안에 있는 요소 중 하나를 리턴
r.sample(l,n) : 안에 잇는 요소 중 n개를 리턴 r.seed() : 시드값 설정

# %%
# numpy

import numpy as np

np.array()
np.arrange()
np.linsapace()
reshape()
np.ones()
np.zeros()
np.eye()
np.empty()
np.full()
np.flatten() / np.ravel()

# %%
# pandas

pd.date_range("20220101", periods=5)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 데이터프레임
# - 시리즈의 집합

# %% [markdown]
# ### 2.1 데이터 세팅
# #### 2.1.1 데이터 저장하기

# %%
# 데이터 저장
df.to_csv("../data/ooo.csv", sep=",", encoding="utf-8") # utf-8-sig도 가능

# %% [markdown]
# #### 2.1.2  데이터 불러오기

# %%
# df = pd.read_확장자('파일명')

df = pd.read_excel('ooo.xlsx')   
df = pd.read_csv('ooo.csv', encoding='utf-8')  

# 한글이 깨지거나 오류가 생기면 cp949 / euc-kr로 인코딩 시도

# %%
# 자료를 읽기 시작할 행(header) 지정
# 인덱스(index_col)로 설정할 컬럼 설정
# 읽어올 엑셀의 컬럼(usecoles) 지정

df = pd.read_excel('ooo.xlsx', header=2, index_col=A, usecols="B, C")

# %%
# df = pd.read_확장자('파일명')
ⓛ df_2 = pd.read_csv('ooo', encoding='utf-8', index_col='기준 열이름')   
② df_2 = pd.read_csv('ooo.csv', encoding='utf-8').set_index('기준 열이름')

# %% [markdown]
# #### 2.1.3 데이터 프레임 직접 생성

# %%
# 딕셔너리 형태로 데이터프레임 생성
df = pd.DataFrame({
        'A': ['1','2','3','4'],
        'B': ['5','6','7','8'],
        'C': ['9','10','11','12']
})

df
# Out:
#    A  B   C
# 0  1  5   9
# 1  2  6  10
# 2  3  7  11
# 3  4  8  12

# %%
# 딕셔너리 형태로 데이터프레임 생성
df = pd.DataFrame([
    {'A':'1', 'B':'5', 'C':'9'},
    {'A':'2', 'B':'6', 'C':'10'},
    {'A':'3', 'B':'7', 'C':'11'},
    {'A':'4', 'B':'8', 'C':'12'}
])

df
# Out:
#    A  B   C
# 0  1  5   9
# 1  2  6  10
# 2  3  7  11
# 3  4  8  12

# %%
# 난수 생성 후 데이터프레임 생성 1

data = np.linspace(0, 1, 25).reshape(5,5)
index_sample = ['idx_1','idx_2','idx_3','idx_4','idx_5']
columns_sample = ['col_1','col_2','col_3','col_4','col_5']

df = pd.DataFrame(data, index=index_sample, columns=columns_sample)
df
# Out:
#           col_1     col_2     col_3     col_4     col_5
# idx_1  0.000000  0.041667  0.083333  0.125000  0.166667
# idx_2  0.208333  0.250000  0.291667  0.333333  0.375000
# idx_3  0.416667  0.458333  0.500000  0.541667  0.583333
# idx_4  0.625000  0.666667  0.708333  0.750000  0.791667
# idx_5  0.833333  0.875000  0.916667  0.958333  1.000000

# %%
# 난수 생성 후 데이터프레임 생성 2
# pd.DataFrame(data, index=oo, columns=xx)
df = pd.DataFrame(np.random.randint(50, 100, size=(10, 5)),
     index = [['1학년' for i in range(5)]+
              ['2학년' for i in range(5)],
              [str(i)+'반' for i in range(1, 6)] + 
              [str(i)+'반' for i in range(1, 6)]],
     columns = ['국', '영', '수', '사', '과'])
df
# Out:
#          국   영   수   사   과
# 1학년 1반  62  78  96  91  61
#     2반  58  62  82  70  71
#     3반  91  86  82  97  75
#     4반  71  72  78  72  94
#     5반  88  78  64  66  69
# 2학년 1반  85  70  93  93  68
#     2반  68  65  77  98  96
#     3반  67  96  95  80  63
#     4반  72  64  58  86  54
#     5반  85  93  96  62  95

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 전처리 방향설정
# ### 2.1 데이터프레임 정보 탐색
# > df.head()
# > df.tail()
# > df.info()
# > df.dtypes
# > df.describe()

# %%
# 예제 데이터 생성

data = np.linspace(0, 1, 25).reshape(5,5)
index_sample = ['idx_1','idx_2','idx_3','idx_4','idx_5']
columns_sample = ['col_1','col_2','col_3','col_4','col_5']

df = pd.DataFrame(data, index=index_sample, columns=columns_sample)
df
# Out:
#           col_1     col_2     col_3     col_4     col_5
# idx_1  0.000000  0.041667  0.083333  0.125000  0.166667
# idx_2  0.208333  0.250000  0.291667  0.333333  0.375000
# idx_3  0.416667  0.458333  0.500000  0.541667  0.583333
# idx_4  0.625000  0.666667  0.708333  0.750000  0.791667
# idx_5  0.833333  0.875000  0.916667  0.958333  1.000000

# %%
# 데이터프레임 상단 n개 행 확인
df.head(2)
# Out:
#           col_1     col_2     col_3     col_4     col_5
# idx_1  0.000000  0.041667  0.083333  0.125000  0.166667
# idx_2  0.208333  0.250000  0.291667  0.333333  0.375000

# %%
# 데이터프레임 하단 n개 행 확인
df.tail(2)
# Out:
#           col_1     col_2     col_3     col_4     col_5
# idx_4  0.625000  0.666667  0.708333  0.750000  0.791667
# idx_5  0.833333  0.875000  0.916667  0.958333  1.000000

# %%
# 데이터프레임 열 타입, 결측값 개수 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, idx_1 to idx_5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   5 non-null      float64
#  1   col_2   5 non-null      float64
#  2   col_3   5 non-null      float64
#  3   col_4   5 non-null      float64
#  4   col_5   5 non-null      float64
# dtypes: float64(5)
# memory usage: 240.0+ bytes

# %%
df.dtypes
# Out:
# col_1    float64
# col_2    float64
# col_3    float64
# col_4    float64
# col_5    float64
# dtype: object

# %%
# 데이터프레임 기술통계 정보 확인
df.describe()
# Out:
#           col_1     col_2     col_3     col_4     col_5
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   0.416667  0.458333  0.500000  0.541667  0.583333
# std    0.329404  0.329404  0.329404  0.329404  0.329404
# min    0.000000  0.041667  0.083333  0.125000  0.166667
# 25%    0.208333  0.250000  0.291667  0.333333  0.375000
# 50%    0.416667  0.458333  0.500000  0.541667  0.583333
# 75%    0.625000  0.666667  0.708333  0.750000  0.791667
# max    0.833333  0.875000  0.916667  0.958333  1.000000

# %% [markdown]
# ### 2.2 인덱스, 컬럼, 값 확인

# %%
df.index
# Out:
# Index(['idx_1', 'idx_2', 'idx_3', 'idx_4', 'idx_5'], dtype='object')

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3', 'col_4', 'col_5'], dtype='object')

# %%
# 해당 컬럼의 중복을 제외한 값들 확인
df['컬럼명'].unique()

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 데이터 전처리
# > 1. 데이터 선택하기
# > 2. 정렬
# > 3. 필터링
# > 4. 결측치 처리
# > 5. 깊은 복사
# > 6. 데이터프레임 복사
# > 7. 생성
# > 8. 변경
# > 9. 연산
# > 10. 삭제
# > 11. pivot, pivot_table
# > 12. 데이터프레임 합치기
# > 13. 멀티인덱스, 멀티컬럼
# > 14. 상관계수
# > 15. itterows

# %% [markdown]
# ### 3.1 데이터 선택하기

# %% [markdown]
# ### 3.1.1 열 선택하기
# > df['A']
# > df.A
# > df[['A']]
# > df[['A','C']]

# %%
# 실습 데이터 생성

data = np.linspace(0, 1, 15).reshape(5,3)
index_sample = pd.date_range("20220101", periods=5)
columns_sample = ['A','B','C']

df = pd.DataFrame(data, index=index_sample, columns=columns_sample)
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 한 개 컬럼 선택
df['A']
# Out:
# 2022-01-01    0.000000
# 2022-01-02    0.214286
# 2022-01-03    0.428571
# 2022-01-04    0.642857
# 2022-01-05    0.857143
# Freq: D, Name: A, dtype: float64

# %%
# 한 개 컬럼 선택
df.A
# Out:
# 2022-01-01    0.000000
# 2022-01-02    0.214286
# 2022-01-03    0.428571
# 2022-01-04    0.642857
# 2022-01-05    0.857143
# Freq: D, Name: A, dtype: float64

# %%
df[['A']]
# Out:
#                    A
# 2022-01-01  0.000000
# 2022-01-02  0.214286
# 2022-01-03  0.428571
# 2022-01-04  0.642857
# 2022-01-05  0.857143

# %%
df[['A','C']]
# Out:
#                    A         C
# 2022-01-01  0.000000  0.142857
# 2022-01-02  0.214286  0.357143
# 2022-01-03  0.428571  0.571429
# 2022-01-04  0.642857  0.785714
# 2022-01-05  0.857143  1.000000

# %% [markdown]
# ---

# %% [markdown]
# ### 3.1.2 행 선택하기

# %% [markdown]
# > df.loc[행이름]
# > df.loc[[행이름]]
# > df.loc[[행이름1, 행이름2]]
# > df[n:m] : n부터 m-1 까지

# %%
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# df.loc[행이름]
df.loc['20220101']
# Out:
# A    0.000000
# B    0.071429
# C    0.142857
# Name: 2022-01-01 00:00:00, dtype: float64

# %%
# df.loc[[행이름]]
df.loc[['20220101']]
# Out:
#               A         B         C
# 2022-01-01  0.0  0.071429  0.142857

# %%
# df.loc[[행이름1, 행이름2]]
df.loc[['20220101','20220105']]
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# df[n:m]
df['20220101':'20220105']
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %% [markdown]
# ---

# %% [markdown]
# ### 3.1.3 특정 값 조회하기
# > df.loc[]
# > df.iloc[]
# > df.at[]

# %% [markdown]
# - df.loc[]

# %%
# 행열 전체
df.loc[:,:]
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 행 3일~5일까지, 열 B부터 C까지
df.loc['20220103':'20220105', 'B':'c']
# Out:
#                    B         C
# 2022-01-03  0.500000  0.571429
# 2022-01-04  0.714286  0.785714
# 2022-01-05  0.928571  1.000000

# %%
# 행 3일~5일까지, 열 B와 C
df.loc['20220103':'20220105', ['B','C']]
# Out:
#                    B         C
# 2022-01-03  0.500000  0.571429
# 2022-01-04  0.714286  0.785714
# 2022-01-05  0.928571  1.000000

# %%
# 행 3일과 5일, 열 B부터 C까지
df.loc[['20220103','20220105'], 'B':'C']
# Out:
#                    B         C
# 2022-01-03  0.500000  0.571429
# 2022-01-05  0.928571  1.000000

# %%
# 행 3일과 5일, 열 B와 C
df.loc[['20220103','20220105'], ['B','C']]
# Out:
#                    B         C
# 2022-01-03  0.500000  0.571429
# 2022-01-05  0.928571  1.000000

# %%
# 행:1월3일, 열:C
df.loc['20220103', 'C']
# Out:
# 0.5714285714285714

# %% [markdown]
# - df.at

# %%
# df.loc['행이름', '열이름']의 결과와 같음
df.at['20220103', 'C']
# Out:
# 0.5714285714285714

# %% [markdown]
# - df.iloc

# %%
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 인덱스 번호 기준 3번째 행
df.iloc[3]
# Out:
# A    0.642857
# B    0.714286
# C    0.785714
# Name: 2022-01-04 00:00:00, dtype: float64

# %%
# 인덱스 번호 기준 3번째 행, 1번째 열
df.iloc[3,1]
# Out:
# 0.7142857142857142

# %%
# 인덱스 번호 기준 0~2번째 행, 0~2번째 열
df.iloc[0:3, 0:3]
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429

# %%
# 인덱스 번호 기준 2번째 행, 0번째/2번째 열
df.iloc[2,[0,2]]
# Out:
# A    0.428571
# C    0.571429
# Name: 2022-01-03 00:00:00, dtype: float64

# %%
# 인덱스 번호 기준 전체 행, 0번째/2번째 열
df.iloc[:,[0,2]]
# Out:
#                    A         C
# 2022-01-01  0.000000  0.142857
# 2022-01-02  0.214286  0.357143
# 2022-01-03  0.428571  0.571429
# 2022-01-04  0.642857  0.785714
# 2022-01-05  0.857143  1.000000

# %%
# 인덱스 번호 기준 0번째/2번째 행, 2번째 열
df.iloc[[0,2], 2]
# Out:
# 2022-01-01    0.142857
# 2022-01-03    0.571429
# Freq: 2D, Name: C, dtype: float64

# %%
# 인덱스 번호 기준 0번째/2번째 행, 전체 열
df.iloc[[0,2], :]
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-03  0.428571  0.500000  0.571429

# %% [markdown]
# ---

# %% [markdown]
# ### 3.2 정렬

# %%
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 오름차순
df.sort_values(by='A', inplace=False) # inplce : 덮어쓰기 여부
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 내림차순
df.sort_values(by='A', ascending=False, inplace=False) # inplce : 덮어쓰기 여부
# Out:
#                    A         B         C
# 2022-01-05  0.857143  0.928571  1.000000
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-01  0.000000  0.071429  0.142857

# %%
# 내부열을 기준열로 설정
df.set_index('A', inplace=False)
# Out:
#                  B         C
# A
# 0.000000  0.071429  0.142857
# 0.214286  0.285714  0.357143
# 0.428571  0.500000  0.571429
# 0.642857  0.714286  0.785714
# 0.857143  0.928571  1.000000

# %%
# df = pd.read_확장자('파일명')
ⓛ df_2 = pd.read_csv('ooo', encoding='utf-8', index_col='기준 열이름')   
② df_2 = pd.read_csv('ooo.csv', encoding='utf-8').set_index('기준 열이름')

# %% [markdown]
# ---

# %% [markdown]
# ### 3.3 필터링

# %% [markdown]
# > df[조건] or df.loc[조건]
# > df.isin()
# > str.contains()
# > 조건을 만족하는 갯수
# > df.isnull()
# > df.isnull.sum()
# > df.notnull()
# > df.notnull().sum()

# %% [markdown]
# - df[조건] or df.loc[조건]

# %%
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 시리즈에 조건을 주면, boolean으로 반환
df['A'] > 0.5
# Out:
# 2022-01-01    False
# 2022-01-02    False
# 2022-01-03    False
# 2022-01-04     True
# 2022-01-05     True
# Freq: D, Name: A, dtype: bool

# %%
# 필터링
df[df['A'] > 0.5]
# Out:
#                    A         B         C
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
df.loc[df['A'] > 0.5, :]
# Out:
#                    A         B         C
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 데이터프레임에 조건을 주면, boolean으로 반환
df[['A','C']] > 0.5
# Out:
#                 A      C
# 2022-01-01  False  False
# 2022-01-02  False  False
# 2022-01-03  False   True
# 2022-01-04   True   True
# 2022-01-05   True   True

# %%
# 필터링
df[df[['A','C']] > 0.5] # NaN : Not a Number
# Out:
#                    A   B         C
# 2022-01-01       NaN NaN       NaN
# 2022-01-02       NaN NaN       NaN
# 2022-01-03       NaN NaN  0.571429
# 2022-01-04  0.642857 NaN  0.785714
# 2022-01-05  0.857143 NaN  1.000000

# %% [markdown]
# - df.isin()

# %%
df['E'] = ['가', '가', '나', '다', '라']
df
# Out:
#                    A         B         C  E
# 2022-01-01  0.000000  0.071429  0.142857  가
# 2022-01-02  0.214286  0.285714  0.357143  가
# 2022-01-03  0.428571  0.500000  0.571429  나
# 2022-01-04  0.642857  0.714286  0.785714  다
# 2022-01-05  0.857143  0.928571  1.000000  라

# %%
df['E'].isin(["가"])
# Out:
# 2022-01-01     True
# 2022-01-02     True
# 2022-01-03    False
# 2022-01-04    False
# 2022-01-05    False
# Freq: D, Name: E, dtype: bool

# %%
df['E'].isin(["가", "다"])
# Out:
# 2022-01-01     True
# 2022-01-02     True
# 2022-01-03    False
# 2022-01-04     True
# 2022-01-05    False
# Freq: D, Name: E, dtype: bool

# %%
# 필터링
df[df['E'].isin(["가", "다"])]
# Out:
#                    A         B         C  E
# 2022-01-01  0.000000  0.071429  0.142857  가
# 2022-01-02  0.214286  0.285714  0.357143  가
# 2022-01-04  0.642857  0.714286  0.785714  다

# %%
# 필터링
df.loc[df['E'].isin(["가", "다"]),:]
# Out:
#                    A         B         C  E
# 2022-01-01  0.000000  0.071429  0.142857  가
# 2022-01-02  0.214286  0.285714  0.357143  가
# 2022-01-04  0.642857  0.714286  0.785714  다

# %% [markdown]
# - str.contains() / sum / value_counts()

# %%
df
# Out:
#                    A         B         C  E
# 2022-01-01  0.000000  0.071429  0.142857  가
# 2022-01-02  0.214286  0.285714  0.357143  가
# 2022-01-03  0.428571  0.500000  0.571429  나
# 2022-01-04  0.642857  0.714286  0.785714  다
# 2022-01-05  0.857143  0.928571  1.000000  라

# %%
df['E'].str.contains('가')
# Out:
# 2022-01-01     True
# 2022-01-02     True
# 2022-01-03    False
# 2022-01-04    False
# 2022-01-05    False
# Freq: D, Name: E, dtype: bool

# %%
df[df['E'].str.contains('가')]
# Out:
#                    A         B         C  E
# 2022-01-01  0.000000  0.071429  0.142857  가
# 2022-01-02  0.214286  0.285714  0.357143  가

# %%
df.loc[df['E'].str.contains('가'), :]
# Out:
#                    A         B         C  E
# 2022-01-01  0.000000  0.071429  0.142857  가
# 2022-01-02  0.214286  0.285714  0.357143  가

# %% [markdown]
# - 조건을 만족하는 갯수

# %%
df
# Out:
#                    A         B         C  E
# 2022-01-01  0.000000  0.071429  0.142857  가
# 2022-01-02  0.214286  0.285714  0.357143  가
# 2022-01-03  0.428571  0.500000  0.571429  나
# 2022-01-04  0.642857  0.714286  0.785714  다
# 2022-01-05  0.857143  0.928571  1.000000  라

# %%
# 컬럼 E의 값의 갯수
df['E'].value_counts()
# Out:
# 가    2
# 라    1
# 다    1
# 나    1
# Name: E, dtype: int64

# %%
# '가'를 요소로 하는 것의 행의 갯수
sum(df['E'].str.contains('가'))
# Out:
# 2

# %%
# 원상복구
del df['E']
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %% [markdown]
# - df.isnull() / df.isnull.sum()

# %%
df['D'] = np.nan
df.iloc[0,3] = 0.275414
df.loc['2022-01-03','D'] = 0.156769
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.000000  0.071429  0.142857  0.275414
# 2022-01-02  0.214286  0.285714  0.357143       NaN
# 2022-01-03  0.428571  0.500000  0.571429  0.156769
# 2022-01-04  0.642857  0.714286  0.785714       NaN
# 2022-01-05  0.857143  0.928571  1.000000       NaN

# %%
df.isnull()
# Out:
#                 A      B      C      D
# 2022-01-01  False  False  False  False
# 2022-01-02  False  False  False   True
# 2022-01-03  False  False  False  False
# 2022-01-04  False  False  False   True
# 2022-01-05  False  False  False   True

# %%
df.isnull().sum()
# Out:
# A    0
# B    0
# C    0
# D    3
# dtype: int64

# %% [markdown]
# - df.notnull() / df.notnull().sum()

# %%
df.notnull()
# Out:
#                A     B     C      D
# 2022-01-01  True  True  True   True
# 2022-01-02  True  True  True  False
# 2022-01-03  True  True  True   True
# 2022-01-04  True  True  True  False
# 2022-01-05  True  True  True  False

# %%
df.notnull().sum()
# Out:
# A    5
# B    5
# C    5
# D    2
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### 3.4 결측치 처리

# %% [markdown]
# > df.dropna()
# > df.fillna()

# %%
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.000000  0.071429  0.142857  0.275414
# 2022-01-02  0.214286  0.285714  0.357143       NaN
# 2022-01-03  0.428571  0.500000  0.571429  0.156769
# 2022-01-04  0.642857  0.714286  0.785714       NaN
# 2022-01-05  0.857143  0.928571  1.000000       NaN

# %%
df.dropna()
# Out:
#                    A         B         C         D
# 2022-01-01  0.000000  0.071429  0.142857  0.275414
# 2022-01-03  0.428571  0.500000  0.571429  0.156769

# %%
df.fillna(1)
# Out:
#                    A         B         C         D
# 2022-01-01  0.000000  0.071429  0.142857  0.275414
# 2022-01-02  0.214286  0.285714  0.357143  1.000000
# 2022-01-03  0.428571  0.500000  0.571429  0.156769
# 2022-01-04  0.642857  0.714286  0.785714  1.000000
# 2022-01-05  0.857143  0.928571  1.000000  1.000000

# %% [markdown]
# ---

# %% [markdown]
# ### 3.5 깊은 복사

# %%
# 얕은 복사 (shallow copy)   
shallow_copy = df
shallow_copy
# Out:
#                    A         B         C         D
# 2022-01-01  0.000000  0.071429  0.142857  0.275414
# 2022-01-02  0.214286  0.285714  0.357143       NaN
# 2022-01-03  0.428571  0.500000  0.571429  0.156769
# 2022-01-04  0.642857  0.714286  0.785714       NaN
# 2022-01-05  0.857143  0.928571  1.000000       NaN

# %%
del shallow_copy['D']
shallow_copy
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 원본 데이터에도 영향을 줌
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 깊은 복사 (deep copy)
deep_copy = df.copy()

# %%
del deep_copy['C']
deep_copy
# Out:
#                    A         B
# 2022-01-01  0.000000  0.071429
# 2022-01-02  0.214286  0.285714
# 2022-01-03  0.428571  0.500000
# 2022-01-04  0.642857  0.714286
# 2022-01-05  0.857143  0.928571

# %%
# 원본 데이터에 영향을 미치지 않음
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %% [markdown]
# ---

# %% [markdown]
# ### 3.5 데이터프레임 복사
# - df의 컬럼을 df_2에 복사할 경우

# %%
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 실습 데이터 생성

data = np.zeros(10).reshape(5,2)
index_sample = pd.date_range("20220101", periods=5)
columns_sample = ['가','나']

df_2 = pd.DataFrame(data, index=index_sample, columns=columns_sample)
df_2
# Out:
#               가    나
# 2022-01-01  0.0  0.0
# 2022-01-02  0.0  0.0
# 2022-01-03  0.0  0.0
# 2022-01-04  0.0  0.0
# 2022-01-05  0.0  0.0

# %%
# 인덱스가 같았을 때 사용 가능
copy_columns=['A','B']
df_2[copy_columns] = df[copy_columns]
df_2
# Out:
#               가    나         A         B
# 2022-01-01  0.0  0.0  0.000000  0.071429
# 2022-01-02  0.0  0.0  0.214286  0.285714
# 2022-01-03  0.0  0.0  0.428571  0.500000
# 2022-01-04  0.0  0.0  0.642857  0.714286
# 2022-01-05  0.0  0.0  0.857143  0.928571

# %%
# 컬럼명을 바꾸어 복사를 할때
df_2[['C','D']] = df[['A','B']]
df_2
# Out:
#               가    나         A         B         C         D
# 2022-01-01  0.0  0.0  0.000000  0.071429  0.000000  0.071429
# 2022-01-02  0.0  0.0  0.214286  0.285714  0.214286  0.285714
# 2022-01-03  0.0  0.0  0.428571  0.500000  0.428571  0.500000
# 2022-01-04  0.0  0.0  0.642857  0.714286  0.642857  0.714286
# 2022-01-05  0.0  0.0  0.857143  0.928571  0.857143  0.928571

# %%
# 원본데이터에 영향 없음
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %% [markdown]
# ---

# %% [markdown]
# ### 3.6 변경

# %% [markdown]
# > 컬럼명, 인덱스명 변경
# > 값 변경
# > 인덱스 초기화
# > 열의 순서 바꾸기

# %% [markdown]
# - 컬럼명, 인덱스명 변경
# - df.rename(columns={'before_1':'after_1'}, index={'before_2':'after_2'}, inplace=True)

# %%
# 원본 데이터 손실 없도록 깊은 복사
df_change = df.copy()
df_change
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
df_change.rename(columns={'A':'a', 'B':'b', 'C':'c'}, inplace=False)
# Out:
#                    a         b         c
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
df_change.rename(index= 
    {df.index[0]:'1일차',
     df.index[1]:'2일차',
     df.index[2]:'3일차',
     df.index[3]:'4일차',
     df.index[4]:'5일차',
    }, inplace=False)
# Out:
#             A         B         C
# 1일차  0.000000  0.071429  0.142857
# 2일차  0.214286  0.285714  0.357143
# 3일차  0.428571  0.500000  0.571429
# 4일차  0.642857  0.714286  0.785714
# 5일차  0.857143  0.928571  1.000000

# %% [markdown]
# - 값 변경
#     - 데이터타입 : astype()
#     - 데이터 변경 : replace()

# %%
df_change = df_change.astype(int)
df_change
# Out:
#             A  B  C
# 2022-01-01  0  0  0
# 2022-01-02  0  0  0
# 2022-01-03  0  0  0
# 2022-01-04  0  0  0
# 2022-01-05  0  0  1

# %%
df_change['C'] = df_change['C'].replace(1, 100)
df_change
# Out:
#             A  B    C
# 2022-01-01  0  0    0
# 2022-01-02  0  0    0
# 2022-01-03  0  0    0
# 2022-01-04  0  0    0
# 2022-01-05  0  0  100

# %% [markdown]
# - 인덱스 초기화

# %%
# drop 인덱스 생성 여부
df_change.reset_index(drop=False, inplace=False)
# Out:
#        index  A  B    C
# 0 2022-01-01  0  0    0
# 1 2022-01-02  0  0    0
# 2 2022-01-03  0  0    0
# 3 2022-01-04  0  0    0
# 4 2022-01-05  0  0  100

# %%
# drop 인덱스 생성 여부
df_change.reset_index(drop=True, inplace=False)
# Out:
#    A  B    C
# 0  0  0    0
# 1  0  0    0
# 2  0  0    0
# 3  0  0    0
# 4  0  0  100

# %% [markdown]
# - 열의 순서 바꾸기

# %%
df_change
# Out:
#             A  B    C
# 2022-01-01  0  0    0
# 2022-01-02  0  0    0
# 2022-01-03  0  0    0
# 2022-01-04  0  0    0
# 2022-01-05  0  0  100

# %%
df_change = df_change[['B','A','C']]
df_change
# Out:
#             B  A    C
# 2022-01-01  0  0    0
# 2022-01-02  0  0    0
# 2022-01-03  0  0    0
# 2022-01-04  0  0    0
# 2022-01-05  0  0  100

# %%
df_change = pd.DataFrame(df_change, columns=['C','B','A'])
df_change
# Out:
#               C  B  A
# 2022-01-01    0  0  0
# 2022-01-02    0  0  0
# 2022-01-03    0  0  0
# 2022-01-04    0  0  0
# 2022-01-05  100  0  0

# %% [markdown]
# ---

# %% [markdown]
# ### 3.7 생성

# %% [markdown]
# #### 3.7.1 컬럼 만들기

# %%
df
# Out:
#                    A         B         C
# 2022-01-01  0.000000  0.071429  0.142857
# 2022-01-02  0.214286  0.285714  0.357143
# 2022-01-03  0.428571  0.500000  0.571429
# 2022-01-04  0.642857  0.714286  0.785714
# 2022-01-05  0.857143  0.928571  1.000000

# %%
# 기존 칼럼이 없으면 추가
# 기존 칼럼이 있으면 수정
# df['A'] = np.nan : NaN 값으로 새로운 열 채우기

df['E'] = ['가', '나', '다', '라', '마']
df
# Out:
#                    A         B         C  E
# 2022-01-01  0.000000  0.071429  0.142857  가
# 2022-01-02  0.214286  0.285714  0.357143  나
# 2022-01-03  0.428571  0.500000  0.571429  다
# 2022-01-04  0.642857  0.714286  0.785714  라
# 2022-01-05  0.857143  0.928571  1.000000  마

# %%
del df['E']

# %% [markdown]
# #### 2.7.2 `apply`

# %% [markdown]
# > sum / np.sum
# > mean / np.mean
# > std / np.std
# > min / np.min
# > max / np.max
# > 람다함수

# %%
# 중앙값
df['A'].apply('sum')
# Out:
# 2.142857142857143

# %%
df['A'].apply(np.sum)
# Out:
# 2022-01-01    0.000000
# 2022-01-02    0.214286
# 2022-01-03    0.428571
# 2022-01-04    0.642857
# 2022-01-05    0.857143
# Freq: D, Name: A, dtype: float64

# %%
# 여러 열을 동시에 함수 적용
df[['A','C']].apply('sum')
# Out:
# A    2.142857
# C    2.857143
# dtype: float64

# %%
# 새로운 열 생성시 함께 사용 가능
df['총합'] = df[['A','B','C']].apply('sum', axis=1)
df
# Out:
#                    A         B         C        총합
# 2022-01-01  0.000000  0.071429  0.142857  0.214286
# 2022-01-02  0.214286  0.285714  0.357143  0.857143
# 2022-01-03  0.428571  0.500000  0.571429  1.500000
# 2022-01-04  0.642857  0.714286  0.785714  2.142857
# 2022-01-05  0.857143  0.928571  1.000000  2.785714

# %%
del df['총합']

# %% [markdown]
# ---

# %% [markdown]
# ### 3.8 연산
# - dtype이 숫자여야 연산이 가능하다

# %%
# 실습 데이터 생성

data = np.linspace(0, 1, 20).reshape(5,4)
index_sample = pd.date_range("20220101", periods=5)
columns_sample = ['A','B','C','D']

df = pd.DataFrame(data, index=index_sample, columns=columns_sample)
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.000000  0.052632  0.105263  0.157895
# 2022-01-02  0.210526  0.263158  0.315789  0.368421
# 2022-01-03  0.421053  0.473684  0.526316  0.578947
# 2022-01-04  0.631579  0.684211  0.736842  0.789474
# 2022-01-05  0.842105  0.894737  0.947368  1.000000

# %% [markdown]
# - df의 열B를 열C로 나누는 두가지 방법

# %%
# case 1
df['C/D_1'] = df['C']/df['D']
df
# Out:
#                    A         B         C         D     C/D_1
# 2022-01-01  0.000000  0.052632  0.105263  0.157895  0.666667
# 2022-01-02  0.210526  0.263158  0.315789  0.368421  0.857143
# 2022-01-03  0.421053  0.473684  0.526316  0.578947  0.909091
# 2022-01-04  0.631579  0.684211  0.736842  0.789474  0.933333
# 2022-01-05  0.842105  0.894737  0.947368  1.000000  0.947368

# %%
# case 2
df['C/D_2'] = df['C'].div(df['D'], axis=0)
df
# Out:
#                    A         B         C         D     C/D_1     C/D_2
# 2022-01-01  0.000000  0.052632  0.105263  0.157895  0.666667  0.666667
# 2022-01-02  0.210526  0.263158  0.315789  0.368421  0.857143  0.857143
# 2022-01-03  0.421053  0.473684  0.526316  0.578947  0.909091  0.909091
# 2022-01-04  0.631579  0.684211  0.736842  0.789474  0.933333  0.933333
# 2022-01-05  0.842105  0.894737  0.947368  1.000000  0.947368  0.947368

# %% [markdown]
# - df의 하나의 컬럼 다수의 컬럼을 나누는 방법

# %%
df[['C/D_3','B/D']] = df[['C','B']].div(df['D'], axis=0)
df
# Out:
#                    A         B         C         D     C/D_1     C/D_2  \
# 2022-01-01  0.000000  0.052632  0.105263  0.157895  0.666667  0.666667
# 2022-01-02  0.210526  0.263158  0.315789  0.368421  0.857143  0.857143
# 2022-01-03  0.421053  0.473684  0.526316  0.578947  0.909091  0.909091
# 2022-01-04  0.631579  0.684211  0.736842  0.789474  0.933333  0.933333
# 2022-01-05  0.842105  0.894737  0.947368  1.000000  0.947368  0.947368
#
#                C/D_3       B/D
# 2022-01-01  0.666667  0.333333
# 2022-01-02  0.857143  0.714286
# 2022-01-03  0.909091  0.818182
# 2022-01-04  0.933333  0.866667
# 2022-01-05  0.947368  0.894737

# %% [markdown]
# ---

# %% [markdown]
# ### 3.9 삭제

# %% [markdown]
# - del : 한 번에 하나만 삭제할 수 있음
# - drop : 여러개를 동시에 삭제할 수 있음

# %%
df
# Out:
#                    A         B         C         D     C/D_1     C/D_2  \
# 2022-01-01  0.000000  0.052632  0.105263  0.157895  0.666667  0.666667
# 2022-01-02  0.210526  0.263158  0.315789  0.368421  0.857143  0.857143
# 2022-01-03  0.421053  0.473684  0.526316  0.578947  0.909091  0.909091
# 2022-01-04  0.631579  0.684211  0.736842  0.789474  0.933333  0.933333
# 2022-01-05  0.842105  0.894737  0.947368  1.000000  0.947368  0.947368
#
#                C/D_3       B/D
# 2022-01-01  0.666667  0.333333
# 2022-01-02  0.857143  0.714286
# 2022-01-03  0.909091  0.818182
# 2022-01-04  0.933333  0.866667
# 2022-01-05  0.947368  0.894737

# %%
del df['C/D_1']
df
# Out:
#                    A         B         C         D     C/D_2     C/D_3  \
# 2022-01-01  0.000000  0.052632  0.105263  0.157895  0.666667  0.666667
# 2022-01-02  0.210526  0.263158  0.315789  0.368421  0.857143  0.857143
# 2022-01-03  0.421053  0.473684  0.526316  0.578947  0.909091  0.909091
# 2022-01-04  0.631579  0.684211  0.736842  0.789474  0.933333  0.933333
# 2022-01-05  0.842105  0.894737  0.947368  1.000000  0.947368  0.947368
#
#                  B/D
# 2022-01-01  0.333333
# 2022-01-02  0.714286
# 2022-01-03  0.818182
# 2022-01-04  0.866667
# 2022-01-05  0.894737

# %%
# 컬럼 하나 삭제
df.drop(['C/D_2'], axis=1, inplace=True)
df
# Out:
#                    A         B         C         D     C/D_3       B/D
# 2022-01-01  0.000000  0.052632  0.105263  0.157895  0.666667  0.333333
# 2022-01-02  0.210526  0.263158  0.315789  0.368421  0.857143  0.714286
# 2022-01-03  0.421053  0.473684  0.526316  0.578947  0.909091  0.818182
# 2022-01-04  0.631579  0.684211  0.736842  0.789474  0.933333  0.866667
# 2022-01-05  0.842105  0.894737  0.947368  1.000000  0.947368  0.894737

# %%
# 컬럼 여러개 삭제
df.drop(['C/D_3','B/D'], axis=1, inplace=True)
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.000000  0.052632  0.105263  0.157895
# 2022-01-02  0.210526  0.263158  0.315789  0.368421
# 2022-01-03  0.421053  0.473684  0.526316  0.578947
# 2022-01-04  0.631579  0.684211  0.736842  0.789474
# 2022-01-05  0.842105  0.894737  0.947368  1.000000

# %%
# 로우 하나 삭제
df.drop([df.index[-1]], axis=0, inplace=True)
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.000000  0.052632  0.105263  0.157895
# 2022-01-02  0.210526  0.263158  0.315789  0.368421
# 2022-01-03  0.421053  0.473684  0.526316  0.578947
# 2022-01-04  0.631579  0.684211  0.736842  0.789474

# %%
# 로우 여러개 삭제
df.drop([df.index[0], df.index[1]], axis=0, inplace=False)
# Out:
#                    A         B         C         D
# 2022-01-03  0.421053  0.473684  0.526316  0.578947
# 2022-01-04  0.631579  0.684211  0.736842  0.789474

# %% [markdown]
# ---

# %% [markdown]
# ### 3.11 pivot, pivot_table

# %% [markdown]
# **pivot**
# - 피벗 필요 요소 : index, columns, values
# - pivot_table과는 달리 연산 불가능

# %%
pivot_df = df.pivot(index='A' , columns='B' , values='C')
pivot_df

# %% [markdown]
# **pivot_table**
# - 피벗테이블 기본 형태 : index, columns, values, aggfunc
# - pivot과는 달리 연산 가능(aggfunc)

# %%
# 기준열로 정렬되며, 숫자데이터가 aggfunc으로 처리된다.
pivot_df = pd.pivot_table(df, index='기준 열이름', aggfunc=np.mean)

# Aggregation function == 집계 함수
# np.mean, np.max, np.min, len ... (평균이 기본 설정값)

# %% [markdown]
# - index, columns, value, aggfunc를 여러개 넣어 사용 가능하다

# %%
df.pivot_table(
    index=["A", "B", "C"],
    columns=["a", "b"],
    values=["1", "2"], 
    aggfunc=[np.sum, np.mean],
    fill_value=0, # NaN 0으로 처리
    margins=True) # 총계(All) 추가

# %% [markdown]
# ---

# %% [markdown]
# ### 3.12 데이터프레임 합치기

# %% [markdown]
# - pd.merge()
# - pd.join()
# - pd.concat()
# - append()

# %% [markdown]
# #### 3.12.1 pd.merge()

# %% [markdown]
# - 두 데이터프레임에 기준이 되는 키값이 모두 있어야 한다

# %%
left = pd.DataFrame({
        'key' : ['K1','K2','K3','K4'],
        'A': ['A1','A2','A3','A4'],
        'B': ['B1','B2','B3','B4']
})

left
# Out:
#   key   A   B
# 0  K1  A1  B1
# 1  K2  A2  B2
# 2  K3  A3  B3
# 3  K4  A4  B4

# %%
right = pd.DataFrame({
        'key' : ['K2','K3','K4','K5'],
        'C': ['C1','C2','C3','C4'],
        'D': ['D1','D2','D3','D4']
})

right
# Out:
#   key   C   D
# 0  K2  C1  D1
# 1  K3  C2  D2
# 2  K4  C3  D3
# 3  K5  C4  D4

# %%
# how ='inner'가 기본 설정값 (교집합)
pd.merge(left,right, on='key')
# Out:
#   key   A   B   C   D
# 0  K2  A2  B2  C1  D1
# 1  K3  A3  B3  C2  D2
# 2  K4  A4  B4  C3  D3

# %%
# 왼쪽에 있는 데이터프레임 기준으로 데이터를 병합
pd.merge(left,right, how='left', on='key')
# Out:
#   key   A   B    C    D
# 0  K1  A1  B1  NaN  NaN
# 1  K2  A2  B2   C1   D1
# 2  K3  A3  B3   C2   D2
# 3  K4  A4  B4   C3   D3

# %%
# 오른쪽에 있는 데이터프레임 기준으로 데이터를 병합
pd.merge(left,right, how='right', on='key')
# Out:
#   key    A    B   C   D
# 0  K2   A2   B2  C1  D1
# 1  K3   A3   B3  C2  D2
# 2  K4   A4   B4  C3  D3
# 3  K5  NaN  NaN  C4  D4

# %%
# 합집합
pd.merge(left,right, how='outer', on='key')
# Out:
#   key    A    B    C    D
# 0  K1   A1   B1  NaN  NaN
# 1  K2   A2   B2   C1   D1
# 2  K3   A3   B3   C2   D2
# 3  K4   A4   B4   C3   D3
# 4  K5  NaN  NaN   C4   D4

# %% [markdown]
# #### 3.12.2 pd.join()

# %% [markdown]
# - 두 데이터프레임의 기준열이 맞지 않아도 합치기 가능
# - 단 행의 길이가 같아야 하며, 열의 이름이 중복되면 안됨

# %%
A = pd.DataFrame({
        'key' : ['K1','K2','K3','K4'],
        'A': ['A1','A2','A3','A4'],
        'B': ['B1','B2','B3','B4']
})

A
# Out:
#   key   A   B
# 0  K1  A1  B1
# 1  K2  A2  B2
# 2  K3  A3  B3
# 3  K4  A4  B4

# %%
B = pd.DataFrame({
        'C': ['C1','C2','C3','C4'],
        'D': ['D1','D2','D3','D4']
})

B
# Out:
#     C   D
# 0  C1  D1
# 1  C2  D2
# 2  C3  D3
# 3  C4  D4

# %%
A.join(B)
# Out:
#   key   A   B   C   D
# 0  K1  A1  B1  C1  D1
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3
# 3  K4  A4  B4  C4  D4

# %%
B.join(A)
# Out:
#     C   D key   A   B
# 0  C1  D1  K1  A1  B1
# 1  C2  D2  K2  A2  B2
# 2  C3  D3  K3  A3  B3
# 3  C4  D4  K4  A4  B4

# %% [markdown]
# #### 3.12.3 pd.concat()
# - pd.concat([A,B], axis=0)

# %%
A = pd.DataFrame({
        'key' : ['K1','K2','K3','K4'],
        'A': ['A1','A2','A3','A4'],
        'B': ['B1','B2','B3','B4']
})

A
# Out:
#   key   A   B
# 0  K1  A1  B1
# 1  K2  A2  B2
# 2  K3  A3  B3
# 3  K4  A4  B4

# %%
B = pd.DataFrame({
        'key' : ['K2','K3','K4','K5'],
        'C': ['C1','C2','C3','C4'],
        'D': ['D1','D2','D3','D4']
})

B
# Out:
#   key   C   D
# 0  K2  C1  D1
# 1  K3  C2  D2
# 2  K4  C3  D3
# 3  K5  C4  D4

# %%
# 행방향으로 병합
pd.concat([A, B], axis = 0)
# Out:
#   key    A    B    C    D
# 0  K1   A1   B1  NaN  NaN
# 1  K2   A2   B2  NaN  NaN
# 2  K3   A3   B3  NaN  NaN
# 3  K4   A4   B4  NaN  NaN
# 0  K2  NaN  NaN   C1   D1
# 1  K3  NaN  NaN   C2   D2
# 2  K4  NaN  NaN   C3   D3
# 3  K5  NaN  NaN   C4   D4

# %%
# 열방향으로 병합
pd.concat([A, B], axis = 1)
# Out:
#   key   A   B key   C   D
# 0  K1  A1  B1  K2  C1  D1
# 1  K2  A2  B2  K3  C2  D2
# 2  K3  A3  B3  K4  C3  D3
# 3  K4  A4  B4  K5  C4  D4

# %%
# concat 옵션
a = pd.DataFrame(['A', 'B', 'C', 'D', 'E','F'], index=range(1, 7))
b = pd.DataFrame(['a', 'b', 'c', 'd', 'e'], index=range(1, 6))
c = pd.DataFrame(['ㄱ', 'ㄴ', 'ㄷ', 'ㄹ', 'ㅁ'], index=range(1, 6))

# %%
pd.concat([a,b,c])
# Out:
#    0
# 1  A
# 2  B
# 3  C
# 4  D
# 5  E
# 6  F
# 1  a
# 2  b
# 3  c
# 4  d
# 5  e
# 1  ㄱ
# 2  ㄴ
# 3  ㄷ
# 4  ㄹ
# 5  ㅁ

# %%
pd.concat([a,b,c], axis=1)
# Out:
#    0  0  0
# 1  A  a  ㄱ
# 2  B  b  ㄴ
# 3  C  c  ㄷ
# 4  D  d  ㄹ
# 5  E  e  ㅁ

# %%
# 교집합
pd.concat([a,b,c], axis=1, join='inner')
# Out:
#    0  0  0
# 1  A  a  ㄱ
# 2  B  b  ㄴ
# 3  C  c  ㄷ
# 4  D  d  ㄹ
# 5  E  e  ㅁ

# %%
# 합집합
pd.concat([a,b,c], axis=1, join='outer')
# Out:
#    0    0    0
# 1  A    a    ㄱ
# 2  B    b    ㄴ
# 3  C    c    ㄷ
# 4  D    d    ㄹ
# 5  E    e    ㅁ
# 6  F  NaN  NaN

# %%
# verify_integrity : 인덱스에 중복되는값이 있을 때, 에러처리
# ignore_index : 인덱스 초기화
# copy : 덮어쓰기 여부
# axis : 0(행방향), 1(열방향)

pd.concat([a, b, c], verify_integrity=False, ignore_index=True, copy=False, axis=1)
# Out:
#    0    1    2
# 1  A    a    ㄱ
# 2  B    b    ㄴ
# 3  C    c    ㄷ
# 4  D    d    ㄹ
# 5  E    e    ㅁ
# 6  F  NaN  NaN

# %% [markdown]
# #### 3.12.3 append()

# %%
a
# Out:
#    0
# 1  A
# 2  B
# 3  C
# 4  D
# 5  E

# %%
a.append(b)
# Out:
#    0
# 1  A
# 2  B
# 3  C
# 4  D
# 5  E
# 1  a
# 2  b
# 3  c
# 4  d
# 5  e

# %%
a.append(b)
# Out:
#    0
# 1  A
# 2  B
# 3  C
# 4  D
# 5  E
# 6  F
# 1  a
# 2  b
# 3  c
# 4  d
# 5  e

# %% [markdown]
# ---

# %% [markdown]
# ### 3.13 멀티인덱스, 멀티컬럼
# > multi index
# > multi coloumns
# > index / slicing

# %% [markdown]
# - multi index

# %%
# 예제 데이터 생성
df_1 = pd.DataFrame(np.random.randint(50, 100, size=(10, 5)),
     index = [['1학년' for i in range(5)]+
              ['2학년' for i in range(5)],
              [str(i)+'반' for i in range(1, 6)] + 
              [str(i)+'반' for i in range(1, 6)]],
     columns = ['국', '영', '수', '사', '과'])
df_1
# Out:
#          국   영   수   사   과
# 1학년 1반  97  65  88  57  53
#     2반  60  74  77  60  95
#     3반  68  64  65  96  84
#     4반  90  69  55  50  82
#     5반  83  51  88  53  97
# 2학년 1반  81  70  53  85  51
#     2반  75  84  91  61  85
#     3반  75  63  90  57  98
#     4반  62  56  92  91  87
#     5반  83  93  65  99  91

# %%
# 인덱스를 단계별로 조회하는 방법
df_1.index.get_level_values
# Out:
# <bound method MultiIndex.get_level_values of MultiIndex([('1학년', '1반'),
#             ('1학년', '2반'),
#             ('1학년', '3반'),
#             ('1학년', '4반'),
#             ('1학년', '5반'),
#             ('2학년', '1반'),
#             ('2학년', '2반'),
#             ('2학년', '3반'),
#             ('2학년', '4반'),
#             ('2학년', '5반')],
#            )>

# %%
df_1.loc['1학년']
# Out:
#      국   영   수   사   과
# 1반  97  65  88  57  53
# 2반  60  74  77  60  95
# 3반  68  64  65  96  84
# 4반  90  69  55  50  82
# 5반  83  51  88  53  97

# %%
df_1.loc['1학년','1반']
# Out:
# 국    97
# 영    65
# 수    88
# 사    57
# 과    53
# Name: (1학년, 1반), dtype: int32

# %%
# 특정 레벨의 컬럼을 제거할 수 있다
df_1.droplevel(axis=0, level=0)
# Out:
#      국   영   수   사   과
# 1반  97  65  88  57  53
# 2반  60  74  77  60  95
# 3반  68  64  65  96  84
# 4반  90  69  55  50  82
# 5반  83  51  88  53  97
# 1반  81  70  53  85  51
# 2반  75  84  91  61  85
# 3반  75  63  90  57  98
# 4반  62  56  92  91  87
# 5반  83  93  65  99  91

# %% [markdown]
# - multi columns

# %%
# 예제 데이터 생성
df_2 = pd.DataFrame(np.random.randint(50, 100, size=(5, 10)),
       index = ['국', '영', '수', '사', '과'],
       columns = [['1학년' for i in range(5)]+
                  ['2학년' for i in range(5)],
                  [str(i)+'반' for i in range(1, 6)] + 
                  [str(i)+'반' for i in range(1, 6)]],)
df_2
# Out:
#   1학년                 2학년
#    1반  2반  3반  4반  5반  1반  2반  3반  4반  5반
# 국  95  89  78  69  95  61  64  76  84  71
# 영  99  70  81  64  50  88  65  62  52  84
# 수  75  76  55  80  76  61  64  97  80  77
# 사  56  67  50  78  76  53  66  54  98  84
# 과  79  70  58  96  67  64  77  59  68  71

# %%
# 컬럼을 단계별로 조회하는 방법
df_2.columns.get_level_values
# Out:
# <bound method MultiIndex.get_level_values of MultiIndex([('1학년', '1반'),
#             ('1학년', '2반'),
#             ('1학년', '3반'),
#             ('1학년', '4반'),
#             ('1학년', '5반'),
#             ('2학년', '1반'),
#             ('2학년', '2반'),
#             ('2학년', '3반'),
#             ('2학년', '4반'),
#             ('2학년', '5반')],
#            )>

# %%
df_2.columns.get_level_values(0)[1]
# Out:
# '1학년'

# %%
# df['level0 컬럼명']['level1 컬럼명']
df_2['1학년']['1반']
# Out:
# 국    95
# 영    99
# 수    75
# 사    56
# 과    79
# Name: 1반, dtype: int32

# %%
# df['level0 컬럼','level1 컬럼','level2 컬럼', ...]
df_2['1학년','1반']
# Out:
# 국    95
# 영    99
# 수    75
# 사    56
# 과    79
# Name: (1학년, 1반), dtype: int32

# %%
# 특정 레벨의 컬럼을 제거할 수 있다
df_2.droplevel(axis=1, level=0)
# Out:
#    1반  2반  3반  4반  5반  1반  2반  3반  4반  5반
# 국  95  89  78  69  95  61  64  76  84  71
# 영  99  70  81  64  50  88  65  62  52  84
# 수  75  76  55  80  76  61  64  97  80  77
# 사  56  67  50  78  76  53  66  54  98  84
# 과  79  70  58  96  67  64  77  59  68  71

# %% [markdown]
# - index, slicing

# %%
df = pd.DataFrame(np.random.randint(50, 100, size=(10, 5)),
     index = [['1학년' for i in range(5)]+
              ['2학년' for i in range(5)],
              [str(i)+'반' for i in range(1, 6)] + 
              [str(i)+'반' for i in range(1, 6)]],
     columns = ['국', '영', '수', '사', '과'])
df
# Out:
#          국   영   수   사   과
# 1학년 1반  84  73  61  91  55
#     2반  61  62  87  94  60
#     3반  77  57  58  91  99
#     4반  71  91  96  77  67
#     5반  72  67  71  72  64
# 2학년 1반  51  93  65  82  93
#     2반  67  60  97  61  52
#     3반  85  76  87  90  63
#     4반  71  51  75  90  62
#     5반  60  64  78  61  70

# %%
# 인덱스
df.loc['1학년','1반']
# Out:
# 국    84
# 영    73
# 수    61
# 사    91
# 과    55
# Name: (1학년, 1반), dtype: int32

# %%
# 인덱스
df[0:1]
# Out:
#          국   영   수   사   과
# 1학년 1반  84  73  61  91  55

# %%
# 컬럼
df['국']
# Out:
# 1학년  1반    84
#      2반    61
#      3반    77
#      4반    71
#      5반    72
# 2학년  1반    51
#      2반    67
#      3반    85
#      4반    71
#      5반    60
# Name: 국, dtype: int32

# %%
# 컬럼
df[['국','영','수']]
# Out:
#          국   영   수
# 1학년 1반  84  73  61
#     2반  61  62  87
#     3반  77  57  58
#     4반  71  91  96
#     5반  72  67  71
# 2학년 1반  51  93  65
#     2반  67  60  97
#     3반  85  76  87
#     4반  71  51  75
#     5반  60  64  78

# %%
# 인덱스 + 컬럼
df.loc['1학년',['국','영','수']]
# Out:
#      국   영   수
# 1반  84  73  61
# 2반  61  62  87
# 3반  77  57  58
# 4반  71  91  96
# 5반  72  67  71

# %%
# 인덱스 + 컬럼 + 정렬`
df.loc['1학년',['국']][::-1]
# Out:
#      국
# 5반  72
# 4반  71
# 3반  77
# 2반  61
# 1반  84

# %%
# 인덱스 + 컬럼 + 정렬
df.iloc[::2, [0, 3]]
# Out:
#          국   사
# 1학년 1반  84  91
#     3반  77  91
#     5반  72  72
# 2학년 2반  67  61
#     4반  71  90

# %%
df_2 = pd.DataFrame(np.random.randint(50, 100, size=(5, 5)),
     index = [['3학년' for i in range(5)],
              [str(i)+'반' for i in range(1, 6)]],
     columns = ['국', '영', '수', '사', '과'])
df_2
# Out:
#          국   영   수   사   과
# 3학년 1반  57  56  87  65  91
#     2반  69  82  61  66  73
#     3반  83  56  70  56  80
#     4반  52  79  77  50  68
#     5반  73  88  94  85  84

# %%
df = df.append(df_2)
df
# Out:
#          국   영   수   사   과
# 1학년 1반  84  73  61  91  55
#     2반  61  62  87  94  60
#     3반  77  57  58  91  99
#     4반  71  91  96  77  67
#     5반  72  67  71  72  64
# 2학년 1반  51  93  65  82  93
#     2반  67  60  97  61  52
#     3반  85  76  87  90  63
#     4반  71  51  75  90  62
#     5반  60  64  78  61  70
# 3학년 1반  57  56  87  65  91
#     2반  69  82  61  66  73
#     3반  83  56  70  56  80
#     4반  52  79  77  50  68
#     5반  73  88  94  85  84

# %%
df['평균'] = (df['국'] + df['영'] + df['수'] + df['사'] + df['과']) / 5
df
# Out:
#          국   영   수   사   과    평균
# 1학년 1반  84  73  61  91  55  72.8
#     2반  61  62  87  94  60  72.8
#     3반  77  57  58  91  99  76.4
#     4반  71  91  96  77  67  80.4
#     5반  72  67  71  72  64  69.2
# 2학년 1반  51  93  65  82  93  76.8
#     2반  67  60  97  61  52  67.4
#     3반  85  76  87  90  63  80.2
#     4반  71  51  75  90  62  69.8
#     5반  60  64  78  61  70  66.6
# 3학년 1반  57  56  87  65  91  71.2
#     2반  69  82  61  66  73  70.2
#     3반  83  56  70  56  80  69.0
#     4반  52  79  77  50  68  65.2
#     5반  73  88  94  85  84  84.8

# %% [markdown]
# ---

# %% [markdown]
# ### 3.14 통계
# > 공분산 : df.cov()
# > 상관계수 (피어슨 상관계수): df.corr()

# %% [markdown]
# #### 3.14.1 공분산
# - 양의 상관관계면 값은 양수 (a 증가시, b 증가)
# - 음의 상관관계면 값은 음수 (a 증가시, b 감소)

# %%
df.cov()
# Out:
#              국           영           수           사           과         평균
# 국   119.980952  -25.166667  -19.842857   59.200000  -32.919048  20.250476
# 영   -25.166667  192.380952   15.785714   12.857143   18.404762  42.852381
# 수   -19.842857   15.785714  175.114286  -16.328571  -57.900000  19.365714
# 사    59.200000   12.857143  -16.328571  217.257143   -1.100000  54.377143
# 과   -32.919048   18.404762  -57.900000   -1.100000  204.495238  26.196190
# 평균   20.250476   42.852381   19.365714   54.377143   26.196190  32.608381

# %% [markdown]
# #### 3.14.2 상관계수 (피어슨 상관계수)
# - 회귀 분석을 통해, 두 변수간의 인과관계의 방향, 정도 등을 확인

# %%
# r이 -1.0과 -0.7 사이이면, 강한 음적 선형관계,
# r이 -0.7과 -0.3 사이이면, 뚜렷한 음적 선형관계,
# r이 -0.3과 -0.1 사이이면, 약한 음적 선형관계,
# r이 -0.1과 +0.1 사이이면, 거의 무시될 수 있는 선형관계,
# r이 +0.1과 +0.3 사이이면, 약한 양적 선형관계,
# r이 +0.3과 +0.7 사이이면, 뚜렷한 양적 선형관계,
# r이 +0.7과 +1.0 사이이면, 강한 양적 선형관계

# %%
# correlation의 약자
df.corr()
# Out:
#            국         영         수         사         과        평균
# 국   1.000000 -0.165649 -0.136895  0.366673 -0.210160  0.323753
# 영  -0.165649  1.000000  0.086005  0.062889  0.092791  0.541040
# 수  -0.136895  0.086005  1.000000 -0.083714 -0.305968  0.256276
# 사   0.366673  0.062889 -0.083714  1.000000 -0.005219  0.646048
# 과  -0.210160  0.092791 -0.305968 -0.005219  1.000000  0.320798
# 평균  0.323753  0.541040  0.256276  0.646048  0.320798  1.000000

# %%
df['국'].corr(df['영'])
# Out:
# -0.16564888206423067

# %% [markdown]
# ---

# %% [markdown]
# ### 3.15 itterows

# %% [markdown]
# - 반복문에서 사용하며, 인덱스와 내용으로 나누어 받을 수 있다.
# - 내용에 있는 값에 접근하는 방법 : rows["열이름"] or rows.열이름

# %%
for idx, rows in df.iterrows():
  print(idx) # 인덱스
  print(rows) # 내용
